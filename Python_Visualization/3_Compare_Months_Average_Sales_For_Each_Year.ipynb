# %% [markdown]
# # **Compare Months Average Sales For Each Year (2022 - 2023):**

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:\\IT Courses\\Data Analysis Courses\\Data Analysis Projects\\Retail Sales Analysis SQL Project\\Retail_Sales_Analysis_SQL_Project\\CSV_Files\\problem_7.csv")

# %%
df
# Out:
#     year  month  sales_average
# 0   2022      1         397.11
# 1   2022      2         366.14
# 2   2022      3         521.38
# 3   2022      4         486.53
# 4   2022      5         480.38
# 5   2022      6         481.40
# 6   2022      7         541.34
# 7   2022      8         385.36
# 8   2022      9         478.84
# 9   2022     10         467.36
# 10  2022     11         472.02
# 11  2022     12         464.20
# 12  2023      1         396.50
# 13  2023      2         535.53
# 14  2023      3         394.81
# 15  2023      4         466.49
# 16  2023      5         450.17
# 17  2023      6         438.48
# 18  2023      7         427.68
# 19  2023      8         495.96
# 20  2023      9         462.74
# 21  2023     10         399.17
# 22  2023     11         453.45
# 23  2023     12         490.39

# %% [markdown]
# ### **Create A Pivot Table To Compare Months Average Sales For Each Year:**

# %%
year_month_pivot = df.pivot_table(
    columns="year",
    index="month",
    values="sales_average"
)
year_month_pivot
# Out:
# year     2022    2023
# month
# 1      397.11  396.50
# 2      366.14  535.53
# 3      521.38  394.81
# 4      486.53  466.49
# 5      480.38  450.17
# 6      481.40  438.48
# 7      541.34  427.68
# 8      385.36  495.96
# 9      478.84  462.74
# 10     467.36  399.17
# 11     472.02  453.45
# 12     464.20  490.39

# %% [markdown]
# ### **Dataset Visualization Using Matplotlib Library:**

# %%
plt.figure(figsize=(15,5))
for column in year_month_pivot.columns:
    plt.plot(
        year_month_pivot.index,
        year_month_pivot[column],
        label=column
    )
plt.title("Average Sales Of Years In Each Month")
plt.xlabel("Months")
plt.ylabel("Average Sales")
plt.xlim(left=year_month_pivot.index.min())
plt.legend(loc='best')
plt.grid()
plt.tight_layout()
